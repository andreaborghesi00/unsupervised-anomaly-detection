# %% [markdown]
# # L05 12/03/24 Lab 01

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./datasets/fortune500(2017-2021).csv', sep=',', index_col=0)
df
# Out:
#       Rank                Name  Revenues($M)  Revenue Percent Change  \
# 0        1             Walmart      559151.0                    0.07
# 1        2              Amazon      386064.0                    0.38
# 2        3               Apple      274515.0                    0.06
# 3        4          CVS Health      268706.0                    0.05
# 4        5  UnitedHealth Group      257141.0                    0.06
# ...    ...                 ...           ...                     ...
# 2495   496       Michaels Cos.        5197.0                    0.06
# 2496   497       Toll Brothers        5170.0                    0.24
# 2497   498               Yahoo        5169.0                    0.04
# 2498   499       Vistra Energy        5164.0                     NaN
# 2499   500      ABM Industries        5145.0                   -0.03
#
#       Profits ($M)  Profits Percent Change  Assets ($M)  \
# 0          13510.0                   -0.09     252496.0
# ...
