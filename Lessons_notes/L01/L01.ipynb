# %% [markdown]
# # L01 04/03/24

# %% [markdown]
# ---

# %% [markdown]
# at the end of the day, even if using machine learning, we have to do fitting of a certaing function.

# %% [markdown]
# **Correlation if different from causation**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3 steps:
# - seeing
# - doing
# - imagining (thinking in retrospective)

# %% [markdown]
# Content of the course:
# - data types, we'll learn to list different data types
# - data preprocessing
# - clustering learning
# - anomaly detection, to find anomalous observations
# - bayesian networks, main topic of professor activity, to learn probabilistic/casual structure from the data
